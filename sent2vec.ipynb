# %%
# !git clone https://github.com/epfml/sent2vec.git
# Out:
# fatal: destination path 'sent2vec' already exists and is not an empty directory.

# %%
# !ls
# Out:
# drive  sample_data  sent2vec

# %%
# %cd sent2vec
# Out:
# /content/sent2vec

# %%
# !ls
# Out:
# args.o						       productquantizer.o
# dictionary.o					       qmatrix.o
# Dockerfile					       README.md
# fasttext					       requirements.txt
# fasttext.o					       setup.py
# get_sentence_embeddings_from_pre-trained_models.ipynb  shmem_matrix.o
# LICENSE						       src
# Makefile					       tweetTokenize.py
# matrix.o					       utils.o
# model.o						       vector.o
# paper-sent2vec.pdf				       wikiTokenize.py

# %%
# !make
# Out:
# make: Nothing to be done for 'opt'.

# %%
# !ls
# Out:
# args.o						       productquantizer.o
# dictionary.o					       qmatrix.o
# Dockerfile					       README.md
# fasttext					       requirements.txt
# fasttext.o					       setup.py
# get_sentence_embeddings_from_pre-trained_models.ipynb  shmem_matrix.o
# LICENSE						       src
# Makefile					       tweetTokenize.py
# matrix.o					       utils.o
# model.o						       vector.o
# paper-sent2vec.pdf				       wikiTokenize.py

# %%
pip install .
# Out:
# Processing /content/sent2vec
# Building wheels for collected packages: sent2vec
#   Building wheel for sent2vec (setup.py) ... done
#   Created wheel for sent2vec: filename=sent2vec-0.0.0-cp36-cp36m-linux_x86_64.whl size=1129516 sha256=b751f8b796aaca5e5ad68ca4dffa52286d98133f8de03dcf5fa699447def2298
#   Stored in directory: /tmp/pip-ephem-wheel-cache-afmzngh1/wheels/b1/65/d7/f2c679e0086741bea69f0c4478303b6506bbf4c78dea82f565
# Successfully built sent2vec
# Installing collected packages: sent2vec
#   Found existing installation: sent2vec 0.0.0
#     Uninstalling sent2vec-0.0.0:
#       Successfully uninstalled sent2vec-0.0.0
# Successfully installed sent2vec-0.0.0

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_directory = "drive/My Drive/MTP/data/"
preprocessed_train_tsv = data_directory + "preprocessed_train.tsv"  #remove ‘content/’ from path then use 
data = pd.read_csv(preprocessed_train_tsv, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-bda49e24c1c2> in <module>()
#       1 data_directory = "drive/My Drive/MTP/data/"
#       2 preprocessed_train_tsv = data_directory + "preprocessed_train.tsv"  #remove ‘content/’ from path then use
# ----> 3 data = pd.read_csv(preprocessed_train_tsv, sep='\t')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File drive/My Drive/MTP/data/preprocessed_train.tsv does not exist: 'drive/My Drive/MTP/data/preprocessed_train.tsv'

# %%
train_txt = data_directory + 'train.txt'

# %%
import sent2vec

# %%
./fasttext sent2vec -input wiki_sentences.txt -output my_model -minCount 8 -dim 700 -epoch 9 -lr 0.2 -wordNgrams 2 -loss ns -neg 10 -thread 20 -t 0.000005 -dropoutK 4 -minCountLabel 20 -bucket 4000000 -maxVocabSize 750000 -numCheckPoints 10
model = fastText.train_supervised(input="train.txt", lr=0.5, epoch=25, wordNgrams=2, bucket=200000, dim=50, loss='hs')
